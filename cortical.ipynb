# %%
import numpy as np
import matplotlib.pyplot as plt
import nibabel as nib
from skimage import filters
from skimage import morphology

# %%
t1 = nib.load("./raw_t1_subject_01.nii.gz").get_fdata();

# %%
tt1 = nib.load("./thickness_map_subject_01.nii.gz").get_fdata();

# %%
t1.shape
# Out:
# (256, 256, 256)

# %%
tt1.shape
# Out:
# (256, 256, 256)

# %%
plt.imshow(t1[:,128,:])

# %%
plt.imshow(tt1[:,128,:])

# %%
t2 = nib.load("./raw_t1_subject_02.nii.gz").get_fdata()

# %%
plt.imshow(t2[:,128,:])
